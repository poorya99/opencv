# %% [markdown]
# <a href="https://colab.research.google.com/github/poorya99/opencv/blob/main/mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jun 24 02:02:15 2017

@author: Saeed Mohaqeqi
"""
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

epochs = 100
batch_size = 128

# Load dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Prepare data
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))  # adapt this if using `channels_first` image data format
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))  # adapt this if using `channels_first` image data format

# Add noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

#===============================================================================
# Design Layers
input_img = Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (7, 7, 32)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# Build the model
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()
#===============================================================================

autoencoder.fit(x_train_noisy, x_train,
                epochs=epochs,
                batch_size=batch_size,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))

#===============================================================================

decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i+1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 469/469 [==============================] - 37s 9ms/step - loss: 0.6830 - val_loss: 0.6679
# Epoch 2/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.6594 - val_loss: 0.6247
# Epoch 3/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.6046 - val_loss: 0.5380
# Epoch 4/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.5204 - val_loss: 0.4988
# Epoch 5/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4915 - val_loss: 0.4852
# Epoch 6/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4786 - val_loss: 0.4721
# Epoch 7/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4655 - val_loss: 0.4591
# Epoch 8/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.4522 - val_loss: 0.4451
# Epoch 9/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4388 - val_loss: 0.4293
# Epoch 10/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4222 - val_loss: 0.4109
# Epoch 11/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.4030 - val_loss: 0.3899
# Epoch 12/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3822 - val_loss: 0.3668
# Epoch 13/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3583 - val_loss: 0.3420
# Epoch 14/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.3341 - val_loss: 0.3168
# Epoch 15/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3098 - val_loss: 0.2936
# Epoch 16/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2877 - val_loss: 0.2739
# Epoch 17/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2694 - val_loss: 0.2579
# Epoch 18/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2545 - val_loss: 0.2454
# Epoch 19/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2432 - val_loss: 0.2357
# Epoch 20/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2339 - val_loss: 0.2280
# Epoch 21/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2271 - val_loss: 0.2216
# Epoch 22/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2208 - val_loss: 0.2163
# Epoch 23/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2153 - val_loss: 0.2116
# Epoch 24/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2109 - val_loss: 0.2076
# Epoch 25/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2074 - val_loss: 0.2040
# Epoch 26/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2039 - val_loss: 0.2008
# Epoch 27/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2009 - val_loss: 0.1979
# Epoch 28/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1982 - val_loss: 0.1953
# Epoch 29/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1955 - val_loss: 0.1929
# Epoch 30/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.1934 - val_loss: 0.1907
# Epoch 31/100
# 469/469 [==============================] - 4s 7ms/step - loss: 0.1911 - val_loss: 0.1886
# Epoch 32/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1890 - val_loss: 0.1867
# Epoch 33/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1872 - val_loss: 0.1849
# Epoch 34/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1855 - val_loss: 0.1832
# Epoch 35/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1838 - val_loss: 0.1817
# Epoch 36/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1823 - val_loss: 0.1802
# Epoch 37/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1805 - val_loss: 0.1788
# Epoch 38/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1793 - val_loss: 0.1775
# Epoch 39/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1782 - val_loss: 0.1763
# Epoch 40/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1770 - val_loss: 0.1752
# Epoch 41/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1760 - val_loss: 0.1740
# Epoch 42/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1748 - val_loss: 0.1730
# Epoch 43/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1737 - val_loss: 0.1720
# Epoch 44/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1730 - val_loss: 0.1711
# Epoch 45/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1720 - val_loss: 0.1702
# Epoch 46/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1712 - val_loss: 0.1694
# Epoch 47/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1704 - val_loss: 0.1685
# Epoch 48/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1695 - val_loss: 0.1678
# Epoch 49/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1687 - val_loss: 0.1670
# Epoch 50/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1675 - val_loss: 0.1663
# Epoch 51/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1672 - val_loss: 0.1656
# Epoch 52/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1663 - val_loss: 0.1649
# Epoch 53/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1659 - val_loss: 0.1642
# Epoch 54/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1651 - val_loss: 0.1636
# Epoch 55/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1646 - val_loss: 0.1630
# Epoch 56/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1639 - val_loss: 0.1624
# Epoch 57/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1633 - val_loss: 0.1618
# Epoch 58/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1626 - val_loss: 0.1612
# Epoch 59/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1623 - val_loss: 0.1607
# Epoch 60/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1617 - val_loss: 0.1601
# Epoch 61/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1611 - val_loss: 0.1596
# Epoch 62/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1607 - val_loss: 0.1591
# Epoch 63/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1601 - val_loss: 0.1586
# Epoch 64/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1596 - val_loss: 0.1581
# Epoch 65/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1591 - val_loss: 0.1576
# Epoch 66/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1585 - val_loss: 0.1571
# Epoch 67/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1582 - val_loss: 0.1565
# Epoch 68/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1576 - val_loss: 0.1560
# Epoch 69/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1571 - val_loss: 0.1555
# Epoch 70/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1564 - val_loss: 0.1551
# Epoch 71/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1560 - val_loss: 0.1546
# Epoch 72/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1557 - val_loss: 0.1541
# Epoch 73/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1550 - val_loss: 0.1537
# Epoch 74/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1547 - val_loss: 0.1533
# Epoch 75/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1544 - val_loss: 0.1528
# Epoch 76/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1539 - val_loss: 0.1524
# Epoch 77/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1534 - val_loss: 0.1520
# Epoch 78/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1533 - val_loss: 0.1516
# Epoch 79/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1524 - val_loss: 0.1512
# Epoch 80/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1521 - val_loss: 0.1508
# Epoch 81/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1521 - val_loss: 0.1504
# Epoch 82/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1516 - val_loss: 0.1500
# Epoch 83/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1512 - val_loss: 0.1497
# Epoch 84/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1508 - val_loss: 0.1493
# Epoch 85/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1504 - val_loss: 0.1489
# Epoch 86/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1500 - val_loss: 0.1485
# Epoch 87/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1498 - val_loss: 0.1482
# Epoch 88/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1494 - val_loss: 0.1478
# Epoch 89/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1489 - val_loss: 0.1475
# Epoch 90/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1487 - val_loss: 0.1471
# Epoch 91/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1483 - val_loss: 0.1468
# Epoch 92/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1477 - val_loss: 0.1465
# Epoch 93/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1478 - val_loss: 0.1461
# Epoch 94/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1474 - val_loss: 0.1458
# Epoch 95/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1469 - val_loss: 0.1455
# Epoch 96/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1469 - val_loss: 0.1452
# Epoch 97/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1463 - val_loss: 0.1448
# Epoch 98/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1460 - val_loss: 0.1445
# Epoch 99/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1457 - val_loss: 0.1442
# Epoch 100/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1451 - val_loss: 0.1439

# %%
x =5

# %%
# jkl
